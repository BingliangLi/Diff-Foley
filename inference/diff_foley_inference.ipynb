# %% [markdown]
# ## Diff-Foley: Inference Pipeline.

# %%
from omegaconf import OmegaConf
import os
import torch
import numpy as np
import librosa
import soundfile as sf
from tqdm import tqdm

import sys
sys.path.append("/".join(os.getcwd().split("/")[:-1]))
from diff_foley.util import instantiate_from_config

# %%
test_list
# Out:
# ['glLQrEijrKg_000300.mp4',
#  'LDoXsip0BEQ_000177.mp4',
#  '6jiO0tPLK7U_000090.mp4',
#  'cRlp5v9BHeE_000011.mp4',
#  'WgZ8KAnnTb8_000030.mp4',
#  'ATnl-fq5nAk_000030.mp4',
#  '20Nlj7Cz4E0_000030.mp4',
#  '2P1uwGQfaPA_000004.mp4',
#  'NlCfScKw_Mk_000030.mp4',
#  'W1nb2hIeDKc_000021.mp4',
#  'QDppmIicknY_000030.mp4',
#  'apZT-WEJ--A_000175.mp4',
#  '7rzEesL55fM_000340.mp4',
#  'BLXwpGCn2KQ_000030.mp4',
#  'xElEg-6DBtM_000018.mp4',
#  'XOI5jgUu3fA_000442.mp4',
#  'hsmrvZEc_uw_000150.mp4',
#  'si_IAMPOXlQ_000170.mp4',
#  '2rK6HBRC8HQ_000040.mp4',
#  'qJ2cY646opA_000000.mp4',
#  '2uYTNgvxVwk_000257.mp4',
#  '8vohm5gaLs8_000049.mp4',
#  '-XxUW9gW6mc_000060.mp4',
#  'wjmMSonpdT0_000030.mp4',
#  'DUlxiX4ri1Q_000045.mp4',
#  'DiBKqoKUjOk_000080.mp4',
#  'KPG9s_s8siA_000030.mp4',
#  'Flusa6-SaDM_000090.mp4',
#  '4q9NPjOpWy8_000146.mp4',
#  '2XQzahrQ_tE_000025.mp4',
#  'MVLEz28ZdFU_000010.mp4',
#  'h_GXTAWpJC8_000002.mp4',
#  'QXnFAcMyAHA_000030.mp4',
#  'JrZZVNhUDtY_000127.mp4',
#  '0_8-g2rof7E_000049.mp4',
#  'EIzBD62ja8E_000030.mp4',
#  'asKuYgAcyIk_000030.mp4',
#  'tV3rvUSlVnY_000030.mp4',
#  'N0c6P3Po5J0_000062.mp4',
#  'aEYwqY-Zt_k_000011.mp4',
#  'GteozUDpJRc_000030.mp4',
#  'hO7Y77gKIMo_000150.mp4',
#  'nEmU3E8rras_000012.mp4',
#  'MnEZwnRuQR8_000030.mp4',
#  'l-qyJLFOVYI_000000.mp4',
#  '1cqcTbDxsHM_000130.mp4',
#  'YXqu1CeA2c4_000044.mp4',
#  '-Tok_g_jgE0_000268.mp4',
#  'puoRo9q7-ec_000009.mp4',
#  'm9jDl571rHU_000010.mp4',
#  '6OjIjy7Hc6I_000030.mp4',
#  'PDToHQeouq8_000050.mp4',
#  'bkIBHUh7LrE_000115.mp4',
#  '4enilF4pEko_000000.mp4',
#  '_547JTmvb9g_000030.mp4',
#  'fYhJdb8ka3k_000030.mp4',
#  'vb1SalyslCs_000050.mp4',
#  'Olfiy3sCF88_000030.mp4',
#  '145N68nh4m0_000130.mp4',
#  'sqGwflGZk4Y_000080.mp4',
#  'DfEOfuu863Q_000016.mp4',
#  'qoo1sZq09pQ_000180.mp4',
#  '9PdzaYwgQBE_000030.mp4',
#  'xw3yx95ZsLg_000030.mp4',
#  'oeNMiCqg9JA_000106.mp4',
#  '1NkUBIl2Plw_000030.mp4',
#  'mcYd-WlyCIw_000006.mp4',
#  'PYislCydAPQ_000030.mp4',
#  'XzsPKZf62G0_000420.mp4',
#  'CDIex7WRfFo_000025.mp4',
#  '4oEjg-ZPXBc_000030.mp4',
#  '40CVvVDVWVM_000051.mp4',
#  'uoCay5JXnn4_000000.mp4',
#  'h4MaAn43I20_000069.mp4',
#  'wCPEfqnHzNc_000067.mp4',
#  'eMQySEjyCUw_000160.mp4',
#  'WSuGM1DGvCM_000006.mp4',
#  'kZegES0woJo_000035.mp4',
#  'zuqaQqmtzXs_000095.mp4',
#  'E4kSn6knAZE_000143.mp4',
#  'BI8YQ3ueD24_000030.mp4',
#  'F5e-SEICJP4_000060.mp4',
#  'hOua7RdPg38_000090.mp4',
#  'mSL8MpANRBE_000013.mp4',
#  'VzB1ly5SirQ_000380.mp4',
#  'dpEVjaFAhAs_000360.mp4',
#  'gyP7-OSixNk_000030.mp4',
#  'mkayu6dgMQs_000190.mp4',
#  'XQHs8qK9HPA_000082.mp4',
#  'bh3M0wYsW1k_000076.mp4',
#  'RvHRucMiAbw_000000.mp4',
#  'YbcsO5O7X9c_000056.mp4',
#  'alYGQZPX7vc_000030.mp4',
#  'khgvtI-pnOE_000012.mp4',
#  'B5KE79I2f-A_000188.mp4',
#  '1_v-Kro86Io_000010.mp4',
#  'MBVEZnvdBUM_000019.mp4',
#  'PuvTDLP8lwM_000030.mp4',
#  'Y16pPj3zfo4_000007.mp4',
#  'rJftCcAQZEY_000460.mp4',
#  '8HUmHsf6dG4_000000.mp4',
#  'aP0nFHftn9A_000070.mp4',
#  'DQRapqt_69c_000128.mp4',
#  'nn5WR8xkcVM_000313.mp4',
#  'doX8FjlNPf8_000030.mp4',
#  'GQb6gTJD7zA_000000.mp4',
#  'SDdlINEPMPc_000030.mp4',
#  'Ahhba-EM4nI_000000.mp4',
#  'ebRLSVHIGEE_000050.mp4',
#  'iPf4W-YgqEs_000120.mp4',
#  'y05npVHuQtg_000024.mp4',
#  'XNGrVxQFrdI_000440.mp4',
#  'HhJNtJYbWkk_000032.mp4',
#  '7GJ9EGKOxSI_000200.mp4',
#  '7-V8cMwkXTk_000030.mp4',
#  'LaiJ0mPbbdk_000016.mp4',
#  'DKrhM5ESJzM_000045.mp4',
#  '4Au6hL7urlY_000368.mp4',
#  'E7qRkUYu580_000307.mp4',
#  'eosvNU2eucs_000260.mp4',
#  'M-bmsXbJBdw_000034.mp4',
#  'Bd-1gr7807g_000016.mp4',
#  'o8_9STVfnvI_000059.mp4',
#  'PeN0BUbCdVE_000030.mp4',
#  'ivKeAXf2H_g_000011.mp4',
#  '680o8EChP_o_000105.mp4',
#  '35HFjLYQiwY_000030.mp4',
#  'NAdLC19r7MU_000245.mp4',
#  'F8OkghIn9L8_000320.mp4',
#  'cM_VbOBRWK8_000000.mp4',
#  'GxT7fj69ni4_000056.mp4',
#  'SM10Hrl5d7U_000010.mp4',
#  'zUxqWMvjKBw_000099.mp4',
#  'QW8-FlKlqAA_000480.mp4',
#  '1MP3sQTk8wo_000000.mp4',
#  'cuINEhfQW98_000109.mp4',
#  'Fnsn0MeW3X4_000580.mp4',
#  'QnR9JhVGgu8_000348.mp4',
#  'idUZsNLnyDg_000030.mp4',
#  'JNvGSWULJLA_000588.mp4',
#  'J3ALZUC6tYI_000065.mp4',
#  'MZEwJXbLjIE_000260.mp4',
#  'ZT3jQW3tvt0_000015.mp4',
#  'ZcQ_w49a8UU_000066.mp4',
#  'pWjfnwWIXQ4_000150.mp4',
#  '25AuI5wE_FM_000004.mp4',
#  'iYBjjt6HwPM_000109.mp4',
#  'MYejbTz5DWY_000166.mp4',
#  'gs-lSymjBVE_000030.mp4',
#  'H4rdJlSSt5Y_000030.mp4',
#  '1BivKH8w7Fo_000037.mp4',
#  'nnkzdwz1D8Q_000280.mp4',
#  '7Tdbu-kCGPI_000077.mp4',
#  '6sRQnpEEQ0E_000390.mp4',
#  '7M8qifHEvQA_000140.mp4',
#  'S0sPNaWcdrs_000043.mp4',
#  'PZJtBkLPDbM_000460.mp4',
#  'xAJtCxlsvGg_000003.mp4',
#  '7L5ceYe0f_s_000120.mp4',
#  '0eTrzI5-ong_000030.mp4',
#  'QXnJ2manIdI_000030.mp4',
#  'qeTDQnAZ81w_000087.mp4',
#  'YCwS46UER0Q_000207.mp4',
#  '6fQqyrMAuFI_000500.mp4',
#  'tQpSR44-vLY_000150.mp4',
#  '2N-TQnG4t90_000045.mp4',
#  'crS5cwurdfY_000160.mp4',
#  'shkxVcpYF8c_000222.mp4',
#  'AG2YTG36nYg_000504.mp4',
#  'cEEoKQ38fHY_000030.mp4',
#  'TCjpetxykx0_000210.mp4',
#  'DqOGYyFVnKk_000200.mp4',
#  'Gx4Ua7b7qcI_000016.mp4',
#  'aEuT4gYoOzg_000020.mp4',
#  'ejg4V7F-ArQ_000327.mp4',
#  'R5I7L3qtgNk_000061.mp4',
#  '2x373CrHD6E_000000.mp4',
#  'Ts3ZcUaELzA_000030.mp4',
#  'R_B5ruT7kAI_000000.mp4',
#  'LmtTU7Ihc4M_000350.mp4',
#  'WMZ3ZAMcE3s_000204.mp4',
#  '99iIggWrfNM_000030.mp4',
#  'B5KE79I2f-A_000220.mp4',
#  '4P518ZMug-U_000115.mp4',
#  'HgSqmsr5GOQ_000030.mp4',
#  'bMYhXjEJl_8_000070.mp4',
#  '4U7GK4-5No4_000046.mp4',
#  'NwBREzh6M_I_000050.mp4',
#  'PeWX2XHqnTw_000005.mp4',
#  'AwAFAi8sa-0_000450.mp4',
#  'KDE80kI1Kf0_000040.mp4',
#  'eZ5iippq3rA_000030.mp4',
#  '7fft0a682rE_000000.mp4',
#  'Bgnaur8-fas_000160.mp4',
#  'mwYb2HLIAmw_000030.mp4',
#  'KqcvoJkKeRk_000081.mp4',
#  'v44s14ocMV4_000033.mp4',
#  'DIAS8gDM8Hg_000003.mp4',
#  'wKVqltUq1Xo_000052.mp4',
#  'ZRVktsXO9FI_000066.mp4',
#  '3LulQoOXNB0_000030.mp4',
#  '1VHm2PacRWc_000020.mp4',
#  'Zbz0xb0BYSk_000090.mp4',
#  'ENX0totqysA_000030.mp4',
#  '2WTk_j_fivY_000030.mp4',
#  'YlLqWCeiVPw_000030.mp4',
#  'QqBqzQofczg_000090.mp4',
#  'adh99_Q735w_000140.mp4',
#  '0NZQRllfNhE_000140.mp4',
#  'R3urUtvSgkU_000030.mp4',
#  'H8q7kRegenA_000490.mp4',
#  'fPAsWpYozPM_000112.mp4',
#  'hnz86eMFjkQ_000002.mp4',
#  'jzxUgRqabsA_000010.mp4',
#  'QJDLZ53UsLk_000320.mp4',
#  'DrN1hZuDLqA_000153.mp4',
#  '4V_-nmgCdCk_000380.mp4',
#  'CnxNaUbF61U_000030.mp4',
#  '99VNZPt2MIs_000126.mp4',
#  'ZsWs23ldI4k_000110.mp4',
#  'N0d1cK2k1Eg_000000.mp4',
#  's6ZrQ73zxdw_000131.mp4',
#  'O_SKumO328I_000030.mp4',
#  'ITKMtPL1pWw_000001.mp4',
#  'EBnrA85wsc4_000030.mp4',
#  'Z0wu_Qi3Cxk_000115.mp4',
#  'qaZYMjKrUCo_000460.mp4',
#  '-G04QpzSpbU_000020.mp4',
#  'hFkC9DzHoho_000189.mp4',
#  'twAF2WFdZMk_000143.mp4',
#  '0hdkmTWLnw8_000042.mp4',
#  'uwH37lkK6OQ_000070.mp4',
#  'Owg_XU9XmRM_000030.mp4',
#  'vhUM-UOKpSk_000053.mp4',
#  '8hE1DIB6wfw_000030.mp4',
#  'r4kvzWLSDT4_000030.mp4',
#  'MI6AgoqRlZg_000069.mp4',
#  'StO32FBBIH4_000011.mp4',
#  'D1VQAb8CfWM_000022.mp4',
#  'Dvq1kY70ip4_000025.mp4',
#  'VCWoxeOUJzc_000083.mp4',
#  'CUWfvJiJFLQ_000030.mp4',
#  'G0SUSiUozWM_000236.mp4',
#  'm-FO9gFY5Go_000030.mp4',
#  'K2pP4vbDrBw_000108.mp4',
#  'wOzgCyoi9l8_000006.mp4',
#  'a2mT_KRRa1Y_000002.mp4',
#  'mZ6ALw9GOUU_000030.mp4',
#  'nxklbthehL0_000100.mp4',
#  'tiMD7FdhbPo_000050.mp4',
#  '3ANlPU9YFmw_000030.mp4',
#  '5NyjOIjRKKM_000018.mp4',
#  'UpTkrr-4feg_000015.mp4',
#  'NwA9JSlK_lM_000030.mp4',
#  'Szwd-0tatdo_000120.mp4',
#  '8n2oR0jgQ5A_000021.mp4',
#  'Hrpr-PM2fQQ_000000.mp4',
#  'V5xL8hLFY58_000030.mp4',
#  'ktLR-WjB_C8_000044.mp4',
#  'RXIRbazT2Rs_000270.mp4',
#  'R_yxyBvaauw_000040.mp4',
#  '2bCuw7U_Rac_000390.mp4',
#  'QDW_uCMnMMU_000000.mp4',
#  '33JKpT0qUcE_000000.mp4',
#  'o1psbzO1YPU_000065.mp4',
#  'V4YUpQKeKD4_000020.mp4',
#  'dgpEiV4huf4_000690.mp4',
#  'MaaPWkNBhR8_000173.mp4',
#  'irHVR7HFtn4_000034.mp4',
#  'Drxkm1HyVxI_000021.mp4',
#  'HZDIyvYqEC8_000066.mp4',
#  '9nNBz3phufo_000040.mp4',
#  'j68v0fnyXg8_000030.mp4',
#  'THhP1idrWXA_000030.mp4',
#  'a6XuFDaKFgM_000092.mp4',
#  'ER1fTL9-pQw_000030.mp4',
#  '-2Dm0VjW8oM_000001.mp4',
#  'PljzqcsQ62U_000030.mp4',
#  'O1RmrE_HfpE_000030.mp4',
#  'NmtINqVMjHE_000258.mp4',
#  'ZvcqyRbXyls_000030.mp4',
#  '986MPr2JYY4_000016.mp4',
#  '4BUKAcdGfaI_000009.mp4',
#  'QS9exOjY2u0_000026.mp4',
#  'W3eYhk9XxRs_000046.mp4',
#  '9koUQIbosEg_000259.mp4',
#  'z55K86oQrMo_000063.mp4',
#  'G4fTKotMoWI_000030.mp4',
#  'rU7WZkmqSGc_000072.mp4',
#  'mCaniZpghFE_000310.mp4',
#  'zsSLTyIhuf0_000000.mp4',
#  'xxxorj7BKe0_000064.mp4',
#  'Aq3pc1q58Kw_000084.mp4',
#  'xsHb8V7bKbo_000010.mp4',
#  '7XNy97YAGjo_000251.mp4',
#  '0J_TdiZ3TKA_000030.mp4',
#  '1zQtgRqPHZU_000046.mp4',
#  'XryEq7dg_fY_000082.mp4',
#  'f9rfsCGlpes_000000.mp4',
#  'cNPwX7nKmOs_000030.mp4',
#  'Y3Iu9Xq-TaU_000505.mp4',
#  'Oct7HCu1Vwo_000035.mp4',
#  '2e1tRszQIPE_000057.mp4',
#  '5gsfdVBThoI_000111.mp4',
#  'cZBUN4-Vu2g_000118.mp4',
#  'LhL0H-LI8SE_000090.mp4',
#  'Gg6Jx9UTBZI_000158.mp4',
#  'W_-t9sBGOg4_000072.mp4',
#  '5QpSgohMobQ_000030.mp4',
#  '-5CGQGSFGyg_000060.mp4',
#  'sP0anQjatZQ_000032.mp4',
#  'tA_NrYVTlps_000024.mp4',
#  'IisvMeU0iKQ_000180.mp4',
#  '3xDZU7GME7E_000170.mp4',
#  'JHAQKzJ43Qo_000110.mp4',
#  'zx_vcwOsDO4_000050.mp4',
#  'gEbqh2WEfKU_000156.mp4',
#  'JzcuvgVgskk_000030.mp4',
#  'ARCyuCLGlmc_000030.mp4',
#  '-hSwZyPPJTc_000075.mp4',
#  'Br2gA432RWo_000182.mp4',
#  'ITym6X1Cvzs_000000.mp4',
#  'CsRF3qYnSLI_000030.mp4',
#  'rXU4vJ4Rz4A_000032.mp4',
#  'L28CnhmeAD4_000030.mp4',
#  'x3i0kNcMM1k_000038.mp4',
#  'G_KiopmUUE0_000000.mp4',
#  'JcLpx0VveSw_000017.mp4',
#  '40AD_oH9eCU_000030.mp4',
#  'E3sbhKh1Rns_000126.mp4',
#  'Sg-8q7jJq7A_000030.mp4',
#  '61krHyjf-ac_000176.mp4',
#  'zBabZOv4dGw_000380.mp4',
#  'JSdALuTneBM_000030.mp4',
#  'vq4jQd5-PL0_000030.mp4',
#  '9lrhuW6aatg_000000.mp4',
#  'ikIVo68HLwY_000010.mp4',
#  '-ABOfhcXwt8_000017.mp4',
#  'QMc3zhoaU-Y_000057.mp4',
#  'X3wyXjui7ac_000213.mp4',
#  'MN-NfHbxdQE_000107.mp4',
#  'x5RTAyFGLRc_000133.mp4',
#  'kXQNBY7Wa14_000030.mp4',
#  'M0GKzxjD9S0_000084.mp4',
#  'wZopmfXTtxw_000030.mp4',
#  '5DN1Q9s5B20_000030.mp4',
#  '7gr6ZOKZwuQ_000010.mp4',
#  'ZPBscuJXkO0_000580.mp4',
#  '_W_Mc16Gi4Q_000030.mp4',
#  'iuXb1ckkpwE_000246.mp4',
#  'CMKnSInoA7I_000003.mp4',
#  'mbIaXWp46po_000088.mp4',
#  '_jB-IM_77lI_000000.mp4',
#  'u-_9D23i6mE_000050.mp4',
#  'mHRF_-IOT2s_000440.mp4',
#  'vyYpxGJr7zI_000030.mp4',
#  'FTOafffuu5U_000150.mp4',
#  'ABs3qGwvW-U_000020.mp4',
#  'xLkLbI6uqSs_000053.mp4',
#  '9fWNP6yAgrU_000003.mp4',
#  'I70DGW_g26g_000100.mp4',
#  '8spcnH0LalI_000032.mp4',
#  'A5lX7rsPIDw_000300.mp4',
#  'U8hJTpSZVWE_000103.mp4',
#  'THu8Uk2KMBM_000030.mp4',
#  'IkS4Dfi2m10_000162.mp4',
#  '9c9dRz8t4bI_000152.mp4',
#  '8TCdnr4F6tw_000303.mp4',
#  '-tptsFSnu60_000235.mp4',
#  'WsHNWjMhlHQ_000452.mp4',
#  'ID9p52w2ah4_000079.mp4',
#  '9K1WO3UNFb0_000269.mp4',
#  'CHkE7YL08Zo_000030.mp4',
#  'IPm036_I75o_000362.mp4',
#  '8UMdVUartLw_000120.mp4',
#  'AucZQ-hal9U_000013.mp4',
#  'DntBIoOgx70_000030.mp4',
#  'sc7KNFUEdfY_000030.mp4',
#  'G-tO6Sqyiu4_000030.mp4',
#  'gLPkzyEy--c_000876.mp4',
#  'FpgEvLIh-jM_000052.mp4',
#  'OvJJbbiz9y8_000070.mp4',
#  'J5E3DDNxZGs_000078.mp4',
#  'J2nDnAerah0_000030.mp4',
#  'DPpmV4JqYsM_000030.mp4',
#  'd_6Ykd2ntDE_000131.mp4',
#  'pOvO5y-p550_000170.mp4',
#  'XCiz7m7HQrs_000120.mp4',
#  'lm5ia1UoyGw_000030.mp4',
#  'nC1p4WWdMgY_000316.mp4',
#  'LoRLOQaZU48_000090.mp4',
#  'sHG7j9-d0d0_000030.mp4',
#  'NV0P4YtItzc_000110.mp4',
#  'q_K7AV8EWks_000026.mp4',
#  'WhBHLyBY5to_000113.mp4',
#  'ysNo8BAeNoE_000037.mp4',
#  'fsHgHsYyJbs_000030.mp4',
#  '3uuyQ4O0L68_000030.mp4',
#  'JIRCCthKAh0_000118.mp4',
#  '7NH1WJlSiYI_000030.mp4',
#  '2Wr7o5BG6e0_000030.mp4',
#  'ifHRDBx-ctw_000030.mp4',
#  'ifGuIUPl1hE_000030.mp4',
#  'FbLFOzKYe-w_000123.mp4',
#  '75PJeJ2hGcw_000030.mp4',
#  '3NRu3vNRFxU_000000.mp4',
#  'Q1n6LAxY7uY_000203.mp4',
#  'sI2qIWCfEJ8_000025.mp4',
#  'KDgNhw175fM_000089.mp4',
#  'KOVw582M79I_000220.mp4',
#  '0BauNGmZtTU_000250.mp4',
#  'AN60q9nSnMk_000030.mp4',
#  'JaKy0YkFdsg_000071.mp4',
#  '5WL7gVP9i58_000121.mp4',
#  'awu8YzLtqF0_000050.mp4',
#  'ucC4clgPd4Q_000030.mp4',
#  'FwVYUHKoLtQ_000034.mp4',
#  'i8kGE-XRat4_000011.mp4',
#  'LExYeHF-ypk_000130.mp4',
#  'wTujz_6ZG9E_000061.mp4',
#  'uG4Y4HedL60_000015.mp4',
#  '28ehZa0fzmo_000028.mp4',
#  'a_tTA5W6FAo_000176.mp4',
#  '4z8HTrCvEsc_000097.mp4',
#  '6LhWo-WzgLU_000034.mp4',
#  'g3eW5ca-DKw_000030.mp4',
#  'RMX2aviLZdo_000070.mp4',
#  '-zSyfcXmHdk_001083.mp4',
#  'xC-FE1l3Cxs_000368.mp4',
#  'K-JfatjTpQw_000119.mp4',
#  'YcBWuQDGrJc_000030.mp4',
#  'KS_5Qiec4AI_000009.mp4',
#  'DmJL3kSguyw_000023.mp4',
#  '8KEzNMLZYpk_000118.mp4',
#  'z16gQeEtuyw_000021.mp4',
#  'P1LygmOqewM_000157.mp4',
#  'CtcmYF7mufk_000030.mp4',
#  'qLQVG0dFvwg_000135.mp4',
#  'DFf71XYDX3g_000016.mp4',
#  '31DHlOBn2LE_000002.mp4',
#  'Pc-XnRIIgqE_000005.mp4',
#  'qgAWtqsSBsg_000035.mp4',
#  'PJnn-wMPU9w_000040.mp4',
#  'ItvWPMW7RWE_000150.mp4',
#  'ZGYQX-172io_000022.mp4',
#  'B2dwWGTj7O4_000400.mp4',
#  'DJbFAoB4-_o_000170.mp4',
#  'ew1epjgvuQM_000030.mp4',
#  'BckOteKD49k_000030.mp4',
#  'xubIj3ag5t4_000233.mp4',
#  'Gr-aT8sYNN8_000030.mp4',
#  'JNE-lrKk6Mg_000030.mp4',
#  'c2akbbdS7I4_000030.mp4',
#  'LuL4ErULWR0_000160.mp4',
#  'B7MStvwQ6R8_000029.mp4',
#  'brfMnl3U64M_000004.mp4',
#  'slbhA0hwhFY_000071.mp4',
#  'HvMZHdzvmSM_000020.mp4',
#  'a23vS080B2E_000100.mp4',
#  'Vo7TOX5_EPQ_000001.mp4',
#  'yL1RQ9FGZyE_000030.mp4',
#  'fFVT_CtL62M_000020.mp4',
#  'psbURlY7H2g_000085.mp4',
#  'WWCNBy_rZzg_000030.mp4',
#  'SwxdBiazu8M_000030.mp4',
#  'nd40lIYtQmA_000138.mp4',
#  'C7hEJn-CQEU_000030.mp4',
#  'DIxTruxPbdk_000000.mp4',
#  'V1M3HiUz0ZQ_000070.mp4',
#  '17K-oEuH1p0_000020.mp4',
#  'DEGSyVygE98_000110.mp4',
#  'oEQT7MSo_aA_000030.mp4',
#  'H6c8ZDrdUaM_000030.mp4',
#  'LyIhmCTPLUc_000030.mp4',
#  '6tRfYp-9YcE_000106.mp4',
#  'qEm2BSgblJ8_000101.mp4',
#  'ALVS3Q_jNaU_000030.mp4',
#  'XOj6xGKEsUw_000035.mp4',
#  'mYbbc_0WyvI_000030.mp4',
#  'gfVNNXPbkW8_000030.mp4',
#  'Sgdq22nyfTM_000240.mp4',
#  'EhaMmYFANQQ_000030.mp4',
#  'Bn2bWpoZOS8_000030.mp4',
#  '0CA5CPHRXDc_000000.mp4',
#  'e4qVs0kpC_w_000510.mp4',
#  's2N0szde6QA_000196.mp4',
#  'dBeRmZn2qCE_000030.mp4',
#  'OwAUGABGrqk_000030.mp4',
#  'A9n6gH2uS5U_000019.mp4',
#  'JrbVM5zjdug_000030.mp4',
#  'pFTAenV8ksU_000030.mp4',
#  '9F1Tw0VnG38_000010.mp4',
#  'KZqhxN-3zzc_000024.mp4',
#  '2aOS7PDaGWM_000092.mp4',
#  'yKZ1wVwmhus_000283.mp4',
#  'bv9PhRwJ9Yc_000000.mp4',
#  'ZJIgxpYf20I_000030.mp4',
#  'y0d6Crj5U8g_000069.mp4',
#  '5hFnrhyWv3c_000027.mp4',
#  'n-A3BJEpmz8_000010.mp4',
#  'aWaMcq7HuKw_000000.mp4',
#  'wWEk1Hl2hK0_000134.mp4',
#  '0SLv6CmZas8_000002.mp4',
#  'DPdAsDw3chc_000030.mp4',
#  'ph2g0DZNiZI_000094.mp4',
#  'LAAB6eDASpE_000361.mp4',
#  '36-Okvu2Xao_000042.mp4',
#  'jv4bWkoG4k8_000310.mp4',
#  '2VqKqjqvugc_000198.mp4',
#  '_Qnw4_agm-0_000030.mp4',
#  'SkIDF7iNJQE_000030.mp4',
#  'ySNRJCMMTu4_000040.mp4',
#  '_6gpB_Trvo8_000000.mp4',
#  'UTE0j8Fa6N8_000030.mp4',
#  'iHYOaGNdweo_000230.mp4',
#  '1EWkwWXwI1g_000210.mp4',
#  '4kGozLe1X_Q_000073.mp4',
#  'Q_J3XkD5Ims_000000.mp4',
#  'EHr7Jjfv1tw_000032.mp4',
#  'Cefeb2q4KSE_000110.mp4',
#  'eipkKgTKAN8_000040.mp4',
#  'oyxhHkOel2I_000115.mp4',
#  'QFyRflnHxxE_000020.mp4',
#  'DC2q5iyvKFM_000060.mp4',
#  'HK6HLZqAe9I_000142.mp4',
#  '7fLnFGd79-s_000018.mp4',
#  'M34hO-PqzpE_000050.mp4',
#  'IoLCBsJC7vw_000011.mp4',
#  'bYQyHfbrq74_000004.mp4',
#  'cxkCPSXyT-Y_000020.mp4',
#  'JS68nchziLA_000029.mp4',
#  'VeAomElRCJc_000030.mp4',
#  'WdIsOZQHeBY_000030.mp4',
#  '2ISY5z0QQfc_000101.mp4',
#  'jna6r3skNeg_000180.mp4',
#  'Gl64LXryFS8_000030.mp4',
#  'vwAXcR6wRuQ_000010.mp4',
#  'KhXcEu7r6m8_000030.mp4',
#  'Ns-iXXKmzzU_000030.mp4',
#  'Kt3KMQU1hJQ_000260.mp4',
#  'SQaFz1SxUyo_000042.mp4',
#  'QC-JCBbOuNc_000030.mp4',
#  'mt2jS_qjpkk_000613.mp4',
#  'ciZjHNKOozg_000210.mp4',
#  '6qX8ykNoVls_000022.mp4',
#  'y3l39BAMaRY_000000.mp4',
#  '8HBG5mO7ef4_000096.mp4',
#  'ub4VKXpuZds_000030.mp4',
#  'fa7iZnVDrJk_000000.mp4',
#  '3IwOig7sw6c_000030.mp4',
#  'J5a_yyh4KbQ_000112.mp4',
#  'HP4bUf_w4hU_000522.mp4',
#  'GmnVEP2AlQI_000102.mp4',
#  'vlNuy9e-79o_000030.mp4',
#  'tRYgfHwu-_U_000019.mp4',
#  'thCn14bf1r8_000380.mp4',
#  'jJ6FWcy7B6M_000052.mp4',
#  'IUgHJv3LBns_000089.mp4',
#  '-OxoxrlzLXA_000045.mp4',
#  'EJIxgOSgE-E_000000.mp4',
#  'FnCrdfgwfdM_000622.mp4',
#  '_mB-DrTf79o_000130.mp4',
#  'JZnOGRCBW0I_000030.mp4',
#  'ebD27_V9zCI_000033.mp4',
#  'GgEOurHF_No_000390.mp4',
#  '3kaCL9Zu7NY_000230.mp4',
#  'zd3SKCVbaWg_000001.mp4',
#  'fFu6-om7EU4_000270.mp4',
#  'HCwHyViV2oU_000073.mp4',
#  '9wUl5xHWcfc_000028.mp4',
#  '0pHTgC1Frnw_000350.mp4',
#  '3X9dtfeV1mQ_000040.mp4',
#  'PBKS0vFpPTk_000016.mp4',
#  'Q4Er5d3L6S0_000005.mp4',
#  'QzMsoz4XIkM_000030.mp4',
#  '2WfJBpN4elI_000020.mp4',
#  'mbVT9tKSUXo_000005.mp4',
#  '9kIBkY7Tj5g_000000.mp4',
#  'NrJMjHIcsto_000140.mp4',
#  'Mr8WsLsNp0A_000002.mp4',
#  'QA4w3EcbBPE_000387.mp4',
#  'LTNgncM_otw_000010.mp4',
#  'UzUTFdlYT68_000055.mp4',
#  'f-22ZuQyAJ4_000119.mp4',
#  '_Bvc901F7Ig_000110.mp4',
#  'AvEJZqK2G1A_000030.mp4',
#  'ce_9wpa4mQw_000230.mp4',
#  'BslzZEEwFa8_000030.mp4',
#  'k211h3tMeGQ_000060.mp4',
#  'AB--KnXO_0c_000030.mp4',
#  '9b3P0ERIZ-c_000053.mp4',
#  '1tn0MJTOprg_000003.mp4',
#  'O_8C1feaFac_000200.mp4',
#  'JKCvfKjTZX8_000050.mp4',
#  'dqt_MzUQ20M_000080.mp4',
#  'H942QC8B3bc_000030.mp4',
#  'ehlYQr1OMxY_000092.mp4',
#  '1ma4b_TsEVA_000320.mp4',
#  'te8Yhl8mOyY_000040.mp4',
#  'VwoaVzQ1uEc_000000.mp4',
#  'R05dToeNqng_000580.mp4',
#  '46gkmd8hhYo_000125.mp4',
#  'tKdeY4KJNWQ_000026.mp4',
#  'bkGy646dRjQ_000030.mp4',
#  'H18aK9HhNSM_000030.mp4',
#  'SkhVlPLx57w_000030.mp4',
#  'g1Mn4tB463U_000160.mp4',
#  'GYQVFv7wGHY_000026.mp4',
#  'L-P2xqZMI8E_000050.mp4',
#  'oTfkeIJmkHw_000224.mp4',
#  'jHs2_FLtd9U_000090.mp4',
#  'lEjV0us_eF0_000021.mp4',
#  'URXTbbVjq70_000040.mp4',
#  '4KxLSx-EhHI_000000.mp4',
#  'I7OqRsLtmh0_000310.mp4',
#  'AAHybONa3n4_000150.mp4',
#  'TNERQa_7oB8_000013.mp4',
#  'OnGPRQdEPWw_000030.mp4',
#  'G0w4RcrTJGA_000009.mp4',
#  'Qovva-Q5vmM_000216.mp4',
#  '3v1pMz1N5RU_000030.mp4',
#  'DCpWtyLjKmM_000030.mp4',
#  '-jaY3LS3Dv0_000030.mp4',
#  'QFovsFrNNfw_000136.mp4',
#  'mMf4vJFT8Fw_000030.mp4',
#  '56JhihsdBXI_000030.mp4',
#  'KIpOaDNuZG4_000110.mp4',
#  'ZxWfqAhmnpg_000050.mp4',
#  'Bj7jRqDk0vE_000280.mp4',
#  '7Qtr6D2TWBE_000350.mp4',
#  'EeGWe8e_2jg_000030.mp4',
#  'RT234P5SzJo_000460.mp4',
#  '2vYkvwD-fkc_000010.mp4',
#  'Sz6nE4hceXc_000030.mp4',
#  '46zbt7TQHRs_000000.mp4',
#  'HINQ5Td2jZc_000090.mp4',
#  'pc-FTQNfxx0_000266.mp4',
#  '2D2AJ6Dg0-U_000162.mp4',
#  '-e4wXAy1iVo_000000.mp4',
#  'ED8UQJIMgeY_000521.mp4',
#  'R-d-5b54PIk_000028.mp4',
#  '2ke9wf3Ajkg_000080.mp4',
#  'LfXdaE7ph_I_000011.mp4',
#  'o9Fiss83B1c_000557.mp4',
#  'YVd117zCTOM_000240.mp4',
#  'YZ1h4yoBqZY_000060.mp4',
#  'm01LHP_3FLY_000203.mp4',
#  'Ay7bs8DMMyA_000005.mp4',
#  '-0pJqpNjft4_000267.mp4',
#  'afYfDTELw4c_000012.mp4',
#  'vh8Uh1zTLQw_000035.mp4',
#  'X071tW0k91Y_000017.mp4',
#  '2v_KyNpsyKs_000030.mp4',
#  'x_5t0os3A2I_000009.mp4',
#  'rNQBarDe0xQ_000072.mp4',
#  'p4myFkq8IMo_000030.mp4',
#  '_PGfCe67Y2Q_000012.mp4',
#  'Wx0Aw9na7Jo_000007.mp4',
#  'Ju1aYoWJM44_000300.mp4',
#  '7uifiqanNoM_000030.mp4',
#  'aU3PT6cU-5g_000395.mp4',
#  '8Q3e7Hvo0zo_000490.mp4',
#  'N0uNunAKh7w_000251.mp4',
#  'Ouxjt5e8x-o_000050.mp4',
#  'OPd0cz1hRqc_000030.mp4',
#  '7B_3t_ELwxA_000030.mp4',
#  '0FHSJnza9P8_000046.mp4',
#  '5uanE7YxW0E_000000.mp4',
#  '7LWqCLxcNXc_000019.mp4',
#  'J3lsvPHrS-8_000577.mp4',
#  'WCUOOS-CtZI_000114.mp4',
#  'gUxQ5nOqusk_000291.mp4',
#  '248HyeJgqyI_000021.mp4',
#  'EFSxZd_eGjM_000017.mp4',
#  'g247CEZ9p70_000010.mp4',
#  'BBRDRggGsdk_000147.mp4',
#  'V3srC9WNp4c_000030.mp4',
#  '0m9-5BkL4Mc_000030.mp4',
#  'JNDvDfDQnJQ_000030.mp4',
#  '-g-GjgEq8l4_000017.mp4',
#  'nUp8SPAWYFo_000070.mp4',
#  '91z1LeIpLbk_000004.mp4',
#  'DWk_7rw81D0_000015.mp4',
#  '-cm0voL_GRM_000322.mp4',
#  'xb07gLlmkL8_000030.mp4',
#  'C0WrPy_cSn4_000100.mp4',
#  'AEwkS57P4eE_000030.mp4',
#  'Qx5trtkwnUk_000377.mp4',
#  'MEUcv-QM0cQ_000030.mp4',
#  '7Cey4yVxuSk_000312.mp4',
#  '6gaZJ-_uEz8_000030.mp4',
#  '2Vg5WTQZqwI_000022.mp4',
#  'JoKMKFX12x8_000003.mp4',
#  'm96TS69ebOI_000404.mp4',
#  'O2HttJtcec4_000030.mp4',
#  'UiqhcbbvAs8_000297.mp4',
#  'pnIQWNmKlQs_000030.mp4',
#  's_8Mu0lIyFg_000151.mp4',
#  'b4glNhNvMYU_000340.mp4',
#  'sG4HCcfAS74_000003.mp4',
#  'CWY1Y5hjfpo_000030.mp4',
#  'I5W0Nnn1zFk_000030.mp4',
#  'ANXFvn9bRN4_000063.mp4',
#  '_z5KQY02rYI_000002.mp4',
#  'WPY9SLh8dwY_000390.mp4',
#  'JgCZbn4JoRY_000030.mp4',
#  'JdBTLOZo3dA_000180.mp4',
#  'wfRWvI16wxw_000047.mp4',
#  'Pjw2A3QU8Qg_000000.mp4',
#  '-OAyRsvFGgc_000030.mp4',
#  'TJ4aeESZ6e8_000100.mp4',
#  'zZYEL5ih3n4_000134.mp4',
#  'j42FvbZ2jjE_000851.mp4',
#  '7MuFNZHhrOE_000330.mp4',
#  '4LwaSleY1Vc_000380.mp4',
#  'VCWoxeOUJzc_000011.mp4',
#  'oU_MZilklxE_000188.mp4',
#  'OODgp3YrENY_000028.mp4',
#  '9r7v3hhUtY4_000004.mp4',
#  '6mgSjz3GufA_000040.mp4',
#  'C5BteXnPQNk_000030.mp4',
#  'Iy2HaWAAnvQ_000173.mp4',
#  'R5dvHVDSXog_000048.mp4',
#  'cjkEA5qjNJo_000210.mp4',
#  '9Vj1UPzlrTc_000030.mp4',
#  '1ENC2smc8Ig_000030.mp4',
#  '1PAb2MoavDc_000210.mp4',
#  'dfwr8wgZU8M_000040.mp4',
#  'jD9UAdvhB6A_000000.mp4',
#  'JV2OwVsxY_0_000000.mp4',
#  'waqwL6fKEE4_000120.mp4',
#  '8UgHOeB_mUE_000399.mp4',
#  'FVXdvx8eBp8_000038.mp4',
#  'cg25DwGFBpw_000165.mp4',
#  'H8IoMxnjzYw_000019.mp4',
#  'qHDSQ2RC-sQ_000030.mp4',
#  'PGbo3Ik8rvI_000034.mp4',
#  '_ZRvQaYLRLw_000030.mp4',
#  '9OcAwC8y-eQ_000030.mp4',
#  'Mjti5KoMVps_000026.mp4',
#  'iUoFC-GUq8o_000113.mp4',
#  '3TRVC6TLnp4_000030.mp4',
#  'ObEtTb5dWgU_000073.mp4',
#  'Iglv2Kru0mw_000040.mp4',
#  'ZkUT6D-H7mk_000006.mp4',
#  'mlpF226Gvlo_000000.mp4',
#  'GoKGgq7BoVM_000010.mp4',
#  '3U99MpJ22ck_000050.mp4',
#  'M4wVyP9D5Qk_000030.mp4',
#  'wZr8jXo1Uso_000102.mp4',
#  'trI_CJMHntA_000000.mp4',
#  'yRBKGI1DjXc_000411.mp4',
#  'JzRb1OVpat0_000030.mp4',
#  '-_yRmyG71Z0_000036.mp4',
#  '9p9Lg1SqJpg_000110.mp4',
#  '9t0s8TUHMiM_000020.mp4',
#  'RjVLYi4jQYc_000000.mp4',
#  'q221aOp6MDo_000033.mp4',
#  '1B-RuZgSqf8_000030.mp4',
#  'VpU4twmXFiI_000010.mp4',
#  'Xrvi5_yQ2hU_000030.mp4',
#  'oqCoWD5LptA_000001.mp4',
#  'i5rLYTVs3uc_000009.mp4',
#  'B98yOZSj2GE_000012.mp4',
#  'jh0nGY4dzHg_000280.mp4',
#  'IL3ThGKdOMk_000221.mp4',
#  'bR8fbwavKtc_000060.mp4',
#  'WmZicfOUkd0_000014.mp4',
#  'ImTFnUGgOZo_000091.mp4',
#  'G_jA6itU_FA_000125.mp4',
#  'bxKdKUZP41Y_000030.mp4',
#  'EYTz1LPDHsc_000017.mp4',
#  'rDb0xQ6m8Oc_000080.mp4',
#  '5EontevWcfQ_000030.mp4',
#  'DUNOn71oGCw_000040.mp4',
#  '784FrdBASsk_000097.mp4',
#  'XIDLRAY7KfQ_000100.mp4',
#  'Cmb7oRnRLio_000083.mp4',
#  't-6BSzXBNbM_000051.mp4',
#  'IHg3nrJZQ1I_000100.mp4',
#  'ehMAmSwqiaA_000061.mp4',
#  'w_JPN_jEzuw_000135.mp4',
#  'brn460KXgfM_000079.mp4',
#  '6r-V0mrdTnQ_000119.mp4',
#  'E4-TY_C4TaI_000194.mp4',
#  'PG9ZRfO9cGI_000003.mp4',
#  'r8EDAvs9gLg_000027.mp4',
#  'cSdSH0LQHfI_000030.mp4',
#  'Uka_Qhmi9cY_000037.mp4',
#  'KPjiLF72m1g_000030.mp4',
#  '72RI4phr0F8_000020.mp4',
#  'g_DBLppDZAs_000030.mp4',
#  '2bYyywE97aA_000030.mp4',
#  '_xsRyM_fXYI_000006.mp4',
#  '7tE6gxSwrH4_000030.mp4',
#  'mZNANTTOh7w_000249.mp4',
#  'Z5XoxwA2e4c_000150.mp4',
#  '6N7IQpJ_yn8_000051.mp4',
#  'QYQEW3Alj78_000111.mp4',
#  'vGxfIpG97dU_000030.mp4',
#  'JXl3VdTNRtA_000020.mp4',
#  'MHcQZKmaOLg_000012.mp4',
#  'vMQqNSEWdGM_000079.mp4',
#  '84TRQfpd8n0_000052.mp4',
#  '2qtDXB4wT8c_000020.mp4',
#  '4Y0Vq_3Lfdk_000180.mp4',
#  'fK9v-WqcoJA_000022.mp4',
#  'o0Sb9ZZaZa0_000000.mp4',
#  'RJOBq50THOk_000030.mp4',
#  'MBVEZnvdBUM_000060.mp4',
#  '6hyBe3FO-xI_000030.mp4',
#  'SGFYFPs3Fic_000550.mp4',
#  'unZVgi2s9w8_000015.mp4',
#  'EzUCugyQf8k_000040.mp4',
#  '84b7NrzJWiI_000420.mp4',
#  'NIRIm_X74e8_000101.mp4',
#  'bzOeufhFITk_000030.mp4',
#  'pJaLxsCM7rc_000190.mp4',
#  'Rg971GlT_Ro_000021.mp4',
#  'fy8xJQ3gXRU_000000.mp4',
#  'mjhlzNVpnXs_000026.mp4',
#  '0loP4WNnL2k_000000.mp4',
#  'U8iIARsN4a4_000004.mp4',
#  '7R11YUfwU50_000164.mp4',
#  'YYgdY9YrVBs_000340.mp4',
#  '_rFtbgF-Im8_000011.mp4',
#  '42vB40Fkdis_000076.mp4',
#  'ZKyVMjSiP7c_000211.mp4',
#  'WvquSD2PcCE_000030.mp4',
#  '72-UFjSlpvM_000314.mp4',
#  'fW6NVxZZekE_000100.mp4',
#  '-inB65exXFU_000030.mp4',
#  'kOheqjodDmw_000050.mp4',
#  'g87FgSOzbvo_000023.mp4',
#  'hrIC-sosqMY_000120.mp4',
#  '1Y2YtG9EX-g_000300.mp4',
#  'gWSppirU_18_000000.mp4',
#  'tNU_9HOjmqQ_000023.mp4',
#  'GdmMt17iklQ_000035.mp4',
#  '0UEWX-2epho_000269.mp4',
#  'ciEKtA13bm8_000000.mp4',
#  'TP-uSCjMiYY_000264.mp4',
#  'REREZlcbGvU_000046.mp4',
#  'wpt_0upWXBY_000301.mp4',
#  'Oj5FYrd3MkQ_000026.mp4',
#  'ioBOW6ynH28_000010.mp4',
#  'kIG_vvycI0g_000285.mp4',
#  'a_kgbg3eDAE_000066.mp4',
#  'ZANp2W2q0XA_000030.mp4',
#  'hhnMBQ3Zgws_000000.mp4',
#  'Qsvip_fmYps_000454.mp4',
#  'mZKUFZhLXAE_000021.mp4',
#  'cjSTp2d8mBI_000459.mp4',
#  'XG1fNGITN08_000400.mp4',
#  'xdTbo10j5tE_000242.mp4',
#  'LY1e2ZUVl8M_000030.mp4',
#  'KI9f7Gclu28_000054.mp4',
#  'Y8x4eyGCecI_000320.mp4',
#  'PdzDGNMpPZc_000520.mp4',
#  'HVSrOlC3270_000045.mp4',
#  'GuYRF0no7hw_000030.mp4',
#  '4mCpxmwhci4_000049.mp4',
#  '__tbvLNH6FI_000110.mp4',
#  '75AjL_RBmfA_000059.mp4',
#  'XvXsYOMYa0k_000157.mp4',
#  '94PSD94IXXk_000016.mp4',
#  'gQby3qzwwQw_000120.mp4',
#  'ZJ3rcQ7kvA8_000632.mp4',
#  '8CqqK9CzuXM_000090.mp4',
#  'P_Gv5_4yNOM_000110.mp4',
#  '0rDaP06do8c_000092.mp4',
#  'avtZJKydB-E_000079.mp4',
#  'mZXjs-SYlCA_000005.mp4',
#  'fqvUeh_JTic_000001.mp4',
#  '8JPwzZvlX6E_000095.mp4',
#  'Wb1u17uxbYU_000304.mp4',
#  'c1dZNH8YiGU_000162.mp4',
#  'RvM9PZB9mqc_000013.mp4',
#  'JHL7f0njYzY_000293.mp4',
#  'p0dBtgjr7-8_000030.mp4',
#  'noXur3qKPQY_000280.mp4',
#  'CSEqIdBIXAY_000030.mp4',
#  'D2IvCQMkGWk_000055.mp4',
#  'VkABXTeQSKk_000099.mp4',
#  'An32hX6i1gs_000030.mp4',
#  '3xh2kScw64U_000030.mp4',
#  '188AGDc9CSY_000070.mp4',
#  'qeVxs9w3g3Q_000455.mp4',
#  '2vFqNsOPq3I_000020.mp4',
#  'BwJ2YYLFwTc_000118.mp4',
#  '421CRF4HFlA_000140.mp4',
#  'dUoUDZYKBzM_000167.mp4',
#  'xh50RF8E2Aw_000038.mp4',
#  'YchzqU8mrmE_000053.mp4',
#  '3MxQpVo8ps4_000088.mp4',
#  'x_5t0os3A2I_000025.mp4',
#  'DybbU7hwzcY_000001.mp4',
#  '1TP8JyI5vHI_000030.mp4',
#  'emP2Sg9QEg4_000090.mp4',
#  'g_H9ViHZ8PA_000045.mp4',
#  'rwU2Pr9gxjo_000108.mp4',
#  '0B7fwvTtvLM_000000.mp4',
#  'Wqux-4IupdU_000112.mp4',
#  'PYqPEeh56fg_000081.mp4',
#  'hRc5mInvrYA_000003.mp4',
#  'jA-9WQtQg-Y_000131.mp4',
#  'guRyU4B5LlA_000030.mp4',
#  's3YWJr87Jsc_000017.mp4',
#  'e5Wu9El1mI4_000156.mp4',
#  'JBKDFk2o5kI_000018.mp4',
#  'CGYflJRiLt0_000030.mp4',
#  't7GM_V8yLqs_000107.mp4',
#  'KMrpYyZNpWw_000025.mp4',
#  'LDpBgaiKB2E_000020.mp4',
#  'pI2gLesgVes_000009.mp4',
#  'tptTsP3_G3w_000834.mp4',
#  'j-bxcM-JXx4_000000.mp4',
#  'Quqx2Iga5b8_000086.mp4',
#  'DcdwmEsIqRQ_000097.mp4',
#  'iuFGMiUE-uI_000012.mp4',
#  '918pICUeEq0_000118.mp4',
#  'cfsOIuZ9G9k_000052.mp4',
#  '6UY-HKyolKk_000030.mp4',
#  'v0a6jM7PALg_000239.mp4',
#  '8kxwzcf54xQ_000088.mp4',
#  'pBWBQYJVbYU_000030.mp4',
#  '2_cTS4ctWtE_000310.mp4',
#  '2gvw16YDwMA_000153.mp4',
#  '58zENxTDTjk_000030.mp4',
#  'hAukn8dWZ2M_000030.mp4',
#  'CDABuTQLNe8_000140.mp4',
#  '8Z2qdI0LlN0_000011.mp4',
#  'fiAJqNva0oA_000030.mp4',
#  'LK0um3j89a0_000030.mp4',
#  'oInlR3rUanI_000080.mp4',
#  'ZIm_awdgw_Q_000181.mp4',
#  'Oj-rWMMAUPU_000090.mp4',
#  'oIUof9ZzRcs_000018.mp4',
#  '84JbG7gFceA_000007.mp4',
#  'h0AQxQzzNt8_000030.mp4',
#  'fLEM7amr21o_000250.mp4',
#  'QyJ4Z0jRJ20_000030.mp4',
#  'ewzjWBrHReg_000144.mp4',
#  'ZqwS3tAXyAg_000450.mp4',
#  'dIzQVYDYtKA_000085.mp4',
#  'O6G5efkuPYQ_000051.mp4',
#  'sNicRCa4sTI_000049.mp4',
#  'RN1ho4G-W0o_000040.mp4',
#  'LsxjV7E7F_M_000097.mp4',
#  'HOhpKjQWqxc_000030.mp4',
#  'v-wAote9cyA_000001.mp4',
#  'yhBm-aCagaY_000565.mp4',
#  'Ucr3WFZk6sM_000020.mp4',
#  'hksYQRPwvc8_000034.mp4',
#  'qZUmCONB6YQ_000022.mp4',
#  'kzWWAUXTv-g_000172.mp4',
#  '0HbhE91JB-k_000360.mp4',
#  'gx6wJrRxq-4_000030.mp4',
#  '_ObtURsKv-U_000001.mp4',
#  'DhMLiwShZss_000137.mp4',
#  'ducLv0cfwVQ_000004.mp4',
#  'Db6Hjt0x28k_000056.mp4',
#  'T2F6euNVT5Y_000010.mp4',
#  '0glBUluF4Yk_000175.mp4',
#  'BQ2om2mrIps_000298.mp4',
#  'Zl29n4sL8_A_000037.mp4',
#  'N0jVgldCwAk_000000.mp4',
#  'LgvmB3oyRWQ_000299.mp4',
#  'RybkZKoNc0s_000030.mp4',
#  'WGYzVpMeSEg_000210.mp4',
#  'kSKXtXXAD70_000030.mp4',
#  'Z22pFIAFD98_000000.mp4',
#  'M0GKzxjD9S0_000347.mp4',
#  'Fg18M9ARcQY_000030.mp4',
#  '6Y3YoMGHufc_000340.mp4',
#  'rQUz1GGqc6E_000333.mp4',
#  'UyCw7pCgYg8_000055.mp4',
#  'nLKEdmVu3FY_000040.mp4',
#  'ybqzgl9OfB8_000364.mp4',
#  'kp5PZawm-X4_000046.mp4',
#  'Cwt7hCUOCDY_000030.mp4',
#  'ROtaeOZoTqU_000196.mp4',
#  'QaKdsbkkmUc_000288.mp4',
#  'ioTmuyoOeV8_000018.mp4',
#  '2UvzCdos0nc_000036.mp4',
#  'UhEQ1E8XPp4_000017.mp4',
#  'JaTfqRN3IrM_000020.mp4',
#  'LfaD5iBSyL4_000092.mp4',
#  'eSSs8vV3VNc_000491.mp4',
#  'k5rDbr_0Ik8_000200.mp4',
#  'ay05WMzpmAk_000035.mp4',
#  'dHM1QdoRmiU_000030.mp4',
#  'QJGordCQPW0_000021.mp4',
#  'kLXnAOe7U0U_000015.mp4',
#  'Fo_FDiZhzDo_000030.mp4',
#  'PeEy6rXMLyg_000035.mp4',
#  'IeapE3z-v3Q_000074.mp4',
#  'gJ1EjXFq5vQ_000410.mp4',
#  'bRCzdN1jfk0_000000.mp4',
#  '5S5RvY9Yups_000175.mp4',
#  ...]

# %% [markdown]
# ### 1. Loading Stage1 CAVP Model:

# %%
import os
from demo_util import Extract_CAVP_Features 

# Set Device:
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda")
# Default Setting:

fps = 4                                                     #  CAVP default FPS=4, Don't change it.
batch_size = 40   # Don't change it.
cavp_config_path = "./config/Stage1_CAVP.yaml"              #  CAVP Config
cavp_ckpt_path = "./diff_foley_ckpt/cavp_epoch66.ckpt"      #  CAVP Ckpt


# Initalize CAVP Model:
extract_cavp = Extract_CAVP_Features(fps=fps, batch_size=batch_size, device=device, config_path=cavp_config_path, ckpt_path=cavp_ckpt_path)

# %% [markdown]
# ### 2. Loading Stage2 LDM Model:

# %%
def load_model_from_config(config, ckpt, verbose=False):
    print(f"Loading model from {ckpt}")
    pl_sd = torch.load(ckpt, map_location="cpu")
    if "global_step" in pl_sd:
        print(f"Global Step: {pl_sd['global_step']}")
    sd = pl_sd["state_dict"]
    model = instantiate_from_config(config.model)
    m, u = model.load_state_dict(sd, strict=False)
    if len(m) > 0 and verbose:
        print("missing keys:")
        print(m)
    if len(u) > 0 and verbose:
        print("unexpected keys:")
        print(u)
    model.cuda()
    model.eval()
    return model

# %%
# LDM Config:
ldm_config_path = "./config/Stage2_LDM.yaml"
ldm_ckpt_path = "./diff_foley_ckpt/ldm_epoch240.ckpt"
config = OmegaConf.load(ldm_config_path)

# Loading LDM:
latent_diffusion_model = load_model_from_config(config, ldm_ckpt_path)

# %% [markdown]
# ### 3. Data Preprocess

# %%
# Sample1:
video_path = "./demo_videos/gun.mp4"
save_path = "./generate_samples/gun"
tmp_path = "./generate_samples/temp_folder" 

## Sample2:
# video_path = "./demo_videos/drum.mp4"
# save_path = "./generate_samples/drum"
# tmp_path = "./generate_samples/temp_folder" 

## Sample3:
# video_path = "./demo_videos/car.mp4"
# save_path = "./generate_samples/car"
# tmp_path = "./generate_samples/temp_folder" 


start_second = 0              # Video start second
truncate_second = 8.2         # Video end = start_second + truncate_second

# Extract Video CAVP Features & New Video Path:
cavp_feats, new_video_path = extract_cavp(video_path, start_second, truncate_second, tmp_path=tmp_path)
# Out:
# video_path ./demo_videos/car.mp4
# truncate second:  8.2
# Processing Frames: 34 Total: 33.0: : 0it [00:00, ?it/s]

# %%
def seed_everything(seed):
    import random, os
    import numpy as np
    import torch
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
seed_everything(21)

# %% [markdown]
# ### 4. Diff-Foley Generation:

# %% [markdown]
# #### 4.(a) Double Guidance Load:

# %%
# Whether use Double Guidance:
use_double_guidance = True

if use_double_guidance:
    classifier_config_path = "./config/Double_Guidance_Classifier.yaml"
    classifier_ckpt_path = "./diff_foley_ckpt/double_guidance_classifier.ckpt"
    classifier_config = OmegaConf.load(classifier_config_path)
    classifier = load_model_from_config(classifier_config, classifier_ckpt_path)

# %%
from demo_util import inverse_op

sample_num = 4

# Inference Param:
cfg_scale = 4.5      # Classifier-Free Guidance Scale
cg_scale = 50        # Classifier Guidance Scale


steps = 25                # Inference Steps

sampler = "DPM_Solver"    # DPM-Solver Sampler
# sampler = "DDIM"        # DDIM Sampler
# sampler = "PLMS"        # PLMS Sampler


save_path = save_path + "_CFG{}_CG{}_{}_{}_useDG_{}".format(cfg_scale, cg_scale, sampler, steps, use_double_guidance)
os.makedirs(save_path, exist_ok=True)

# Video CAVP Features:
video_feat = torch.from_numpy(cavp_feats).unsqueeze(0).repeat(sample_num, 1, 1).to(device)
print(video_feat.shape)


# Truncate the Video Cond:
feat_len = video_feat.shape[1]
truncate_len = 32
window_num = feat_len // truncate_len


audio_list = []     # [sample_list1, sample_list2, sample_list3 ....]
for i in tqdm(range(window_num), desc="Window:"):
    start, end = i * truncate_len, (i+1) * truncate_len
    
    # 1). Get Video Condition Embed:
    embed_cond_feat = latent_diffusion_model.get_learned_conditioning(video_feat[:, start:end])     

    # 2). CFG unconditional Embedding:
    uncond_cond = torch.zeros(embed_cond_feat.shape).to(device)
    
    # 3). Diffusion Sampling:
    print("Using Double Guidance: {}".format(use_double_guidance))
    if use_double_guidance:
        audio_samples, _ = latent_diffusion_model.sample_log_with_classifier_diff_sampler(embed_cond_feat, origin_cond=video_feat, batch_size=video_feat.shape[0], sampler_name=sampler, ddim_steps=steps, unconditional_guidance_scale=cfg_scale,unconditional_conditioning=uncond_cond,classifier=classifier, classifier_guide_scale=cg_scale)  # Double Guidance
    else:
        audio_samples, _ = latent_diffusion_model.sample_log_diff_sampler(embed_cond_feat, batch_size=sample_num, sampler_name=sampler, ddim_steps=steps, unconditional_guidance_scale=cfg_scale,unconditional_conditioning=uncond_cond)           #  Classifier-Free Guidance
 
    # 4). Decode Latent:
    audio_samples = latent_diffusion_model.decode_first_stage(audio_samples)                     
    audio_samples = audio_samples[:, 0, :, :].detach().cpu().numpy()                               

    # 5). Spectrogram -> Audio:  (Griffin-Lim Algorithm)
    sample_list = []        #    [sample1, sample2, ....]
    for k in tqdm(range(audio_samples.shape[0]), desc="current samples:"):
        sample = inverse_op(audio_samples[k])
        sample_list.append(sample)
    audio_list.append(sample_list)
# Out:
# torch.Size([4, 33, 512])
# Window::   0%|          | 0/1 [00:00<?, ?it/s]
# Using Double Guidance: True
# current samples:: 100%|██████████| 4/4 [00:24<00:00,  6.10s/it]
# Window:: 100%|██████████| 1/1 [00:29<00:00, 29.98s/it]

# %%
# Save Samples:
path_list = []
for i in range(sample_num):      # sample_num
    current_audio_list = []
    for k in range(window_num):
        current_audio_list.append(audio_list[k][i])
    current_audio = np.concatenate(current_audio_list,0)
    print(current_audio.shape)
    sf.write(os.path.join(save_path, "sample_{}_diff.wav").format(i), current_audio, 16000)
    path_list.append(os.path.join(save_path, "sample_{}_diff.wav").format(i))
print("Gen Success !!")
# Out:
# (130816,)
# (130816,)
# (130816,)
# (130816,)
# Gen Success !!

# %%
# Concat The Video and Sound:
import subprocess
src_video_path = new_video_path
for i in range(sample_num):
    gen_audio_path = path_list[i]
    out_path = os.path.join(save_path, "output_{}.mp4".format(i))
    cmd = ["ffmpeg" ,"-i" ,src_video_path,"-i" , gen_audio_path ,"-c:v" ,"copy" ,"-c:a" ,"aac" ,"-strict" ,"experimental", out_path]
    # cmd = ["ffmpeg" ,"-i" ,src_video_path,"-i" , gen_audio_path ,"-c:v" ,"copy" ,"-c:a" ,"mp3" ,"-strict" ,"experimental", out_path]
    subprocess.check_call(cmd)
print("Gen Success !!")
# Out:
# Gen Success !!
